# %%
import numpy as np
import pandas as pd

data = pd.read_csv("train.csv")
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
len(data)
# Out:
# 891

# %%
test = pd.read_csv("test.csv")
len(test)
# Out:
# 418

# %%
d = pd.read_excel("titanic3.xls")
len(d)
# Out:
# 1309

# %%
del d['boat']
del d['body']

# %%
labels = d['survived']

# %%
d
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen, Miss. Elisabeth Walton
# 1          1         1                     Allison, Master. Hudson Trevor
# 2          1         0                       Allison, Miss. Helen Loraine
# 3          1         0               Allison, Mr. Hudson Joshua Creighton
# 4          1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                                Anderson, Mr. Harry
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 7          1         0                             Andrews, Mr. Thomas Jr
# 8          1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                            Artagaveytia, Mr. Ramon
# 10         1         0                             Astor, Col. John Jacob
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %%
dnew = d.sample(frac = 1)

# %%
dnew = dnew.reset_index()
del dnew['index']

# %%
dnew
# Out:
#       pclass  survived                                               name  \
# 0          3         0                                 Markoff, Mr. Marin
# 1          3         0                             Celotti, Mr. Francesco
# 2          1         1                         Fortune, Miss. Mabel Helen
# 3          3         0                              Barbara, Miss. Saiide
# 4          3         1                            de Mulder, Mr. Theodore
# 5          2         0                          Deacon, Mr. Percy William
# 6          2         1  Laroche, Mrs. Joseph (Juliette Marie Louise La...
# 7          3         0            Rasmussen, Mrs. (Lena Jacobsen Solvang)
# 8          3         1    Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 9          2         0                               Bowenur, Mr. Solomon
# 10         3         0                     Coelho, Mr. Domingos Fernandeo
# 11         2         1                                Toomey, Miss. Ellen
# ...

# %%
del dnew['home.dest']

# %%
dnew = dnew.reset_index()
dnew.rename(columns = {'index':'Pid'},inplace = True)

# %%
dnew
# Out:
#        Pid  pclass  survived  \
# 0        0       3         0
# 1        1       3         0
# 2        2       1         1
# 3        3       3         0
# 4        4       3         1
# 5        5       2         0
# 6        6       2         1
# 7        7       3         0
# 8        8       3         1
# 9        9       2         0
# 10      10       3         0
# 11      11       2         1
# 12      12       2         1
# 13      13       1         0
# 14      14       3         0
# 15      15       1         1
# 16      16       3         0
# 17      17       3         0
# 18      18       1         1
# 19      19       3         0
# 20      20       1         0
# 21      21       1         0
# 22      22       3         0
# 23      23       3         1
# 24      24       3         0
# 25      25       3         0
# 26      26       3         0
# 27      27       1         0
# 28      28       2         0
# 29      29       3         0
# ...    ...     ...       ...
# ...

# %%
X_train = dnew[:877]

# %%
X_test = dnew[878:]

# %%
len(X_train)
# Out:
# 877

# %%
len(X_test)
# Out:
# 431

# %%
X_train.to_csv("train.csv")

# %%
X_test.drop(labels=['survived'],axis=1).to_csv('test.csv')

# %%
t1 = X_test[['Pid','survived']].reset_index()
del t1['index']
t1.to_csv("solutions.csv")

# %%
temp = X_test

# %%
temp['survived'] = 0
# Out:
# /home/pratik/.local/lib/python3.5/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
del X_test['survived']

# %%
t=pd.read_csv('solutions.csv')
X_test['survived']=t['survived'].tolist()
# Out:
# /home/pratik/.local/lib/python3.5/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
X_test.to_csv("final_test.csv")
