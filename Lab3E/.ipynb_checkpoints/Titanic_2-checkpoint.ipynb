# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

full_data = pd.read_csv('train.csv')
full_data.head()
test_data = pd.read_csv('final_test.csv')

# %%
outcomes = full_data['survived']
data = full_data.drop('survived', axis = 1)
test_outcomes = test_data['survived']
test_data = test_data.drop('survived',axis=1)

# %%
sns.countplot(x='sex',hue='survived',data = full_data)

plt.show()
# Out:
# /home/pratik/.local/lib/python3.5/site-packages/seaborn/categorical.py:1468: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data[hue_mask])

# %%
sns.countplot(x='parch',hue='survived',data = full_data[full_data['sex']=='male'])

plt.show()
# Out:
# /home/pratik/.local/lib/python3.5/site-packages/seaborn/categorical.py:1468: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data[hue_mask])

# %%
sns.countplot(x='pclass',hue='survived',data = full_data[(full_data['sex']=='male')&(full_data['parch']!=0)])

plt.show()
# Out:
# /home/pratik/.local/lib/python3.5/site-packages/seaborn/categorical.py:1468: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data[hue_mask])

# %%
temp = full_data[(full_data['sex']=='male')&(full_data['parch']!=0)&(full_data['survived']==1)]
sns.distplot(temp['age'].fillna(temp['age'].mean()),kde=False)

plt.show()

# %%
def predictions_3(data):
    
    
    predictions = []
    for _, passenger in data.iterrows():     
        if(passenger["sex"]=="female"):
            predictions.append(1)
        elif(passenger["parch"]==0):
            predictions.append(0)
        elif(passenger["pclass"]==3):
            predictions.append(0)
        elif(passenger["age"]<18):
            predictions.append(1)
        else:
            predictions.append(0)
        
    return pd.Series(predictions)


predictions = predictions_3(test_data)

# %%
from sklearn.metrics import accuracy_score

print (accuracy_score(test_outcomes, predictions))
# Out:
# 0.7819025522041764
