# %%
import numpy as np
import pandas as pd

# %%
d = pd.read_excel("titanic3.xls")
len(d)
# Out:
# 1309

# %%
del d['boat']
del d['body']
del d['home.dest']

# %%
labels = d['survived']

# %%
d
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen, Miss. Elisabeth Walton
# 1          1         1                     Allison, Master. Hudson Trevor
# 2          1         0                       Allison, Miss. Helen Loraine
# 3          1         0               Allison, Mr. Hudson Joshua Creighton
# 4          1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                                Anderson, Mr. Harry
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 7          1         0                             Andrews, Mr. Thomas Jr
# 8          1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                            Artagaveytia, Mr. Ramon
# 10         1         0                             Astor, Col. John Jacob
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %%
dnew = d.sample(frac = 1)

# %%
dnew = dnew.reset_index()
del dnew['index']

# %%
dnew
# Out:
#       pclass  survived                                               name  \
# 0          3         0                           Allen, Mr. William Henry
# 1          2         1                                  Davis, Miss. Mary
# 2          1         1                              Bazzani, Miss. Albina
# 3          2         1              Richards, Mrs. Sidney (Emily Hocking)
# 4          3         0                       Panula, Master. Eino Viljami
# 5          1         0             Williams-Lambert, Mr. Fletcher Fellows
# 6          1         1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 7          2         0                             Harbeck, Mr. William H
# 8          1         1                               Daniels, Miss. Sarah
# 9          3         0                                Murdlin, Mr. Joseph
# 10         1         1                   Flynn, Mr. John Irwin ("Irving")
# 11         1         1                       Sloper, Mr. William Thompson
# ...

# %%
dnew = dnew.reset_index()
dnew.rename(columns = {'index':'Pid'},inplace = True)

# %%
dnew
# Out:
#        Pid  pclass  survived  \
# 0        0       3         0
# 1        1       2         1
# 2        2       1         1
# 3        3       2         1
# 4        4       3         0
# 5        5       1         0
# 6        6       1         1
# 7        7       2         0
# 8        8       1         1
# 9        9       3         0
# 10      10       1         1
# 11      11       1         1
# 12      12       2         1
# 13      13       2         0
# 14      14       3         1
# 15      15       1         1
# 16      16       3         1
# 17      17       3         1
# 18      18       2         1
# 19      19       1         0
# 20      20       3         0
# 21      21       3         0
# 22      22       1         1
# 23      23       3         0
# 24      24       2         0
# 25      25       1         1
# 26      26       1         1
# 27      27       2         1
# 28      28       2         0
# 29      29       2         1
# ...    ...     ...       ...
# ...

# %%
X_train = dnew[:877]

# %%
X_test = dnew[878:]

# %%
len(X_train)
# Out:
# 877

# %%
len(X_test)
# Out:
# 431

# %%
X_train.to_csv("train.csv",index = False)

# %%
X_test.drop(labels=['survived'],axis=1).to_csv('test.csv',index=False)

# %%
t1 = X_test[['Pid','survived']]
t1.to_csv("solutions.csv",index = False)

# %%
X_test.to_csv("final_test.csv",index=False)

# %%
sample = pd.read_csv("solutions.csv")

# %%
sample['survived'] = 0

# %%
sample.to_csv('sample_solutions.csv',index=False)
